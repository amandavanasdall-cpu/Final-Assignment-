# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/healthcare_spending.csv")

print("Healthcare Spending Data:")
print(df.head())
# Out:
# Healthcare Spending Data:
#    age  gender        income  utilities  entertainment  school_fees  shopping  \
# 0   23  Female  1.234400e+04      123.0           1.99         24.0      53.0
# 1   12  Female  1.234553e+10       24.0          25.00         12.0     235.0
#
#    healthcare
# 0        34.0
# 1       324.0
